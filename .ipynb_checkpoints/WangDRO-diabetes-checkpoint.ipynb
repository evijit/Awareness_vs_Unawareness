# %%
import os,sys,json
from glob import glob

os.chdir('/home/avijit/projects/Awareness_vs_Unawareness')
sys.path.insert(0,"/home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode")

# %%
import warnings
warnings.filterwarnings('ignore')

from robustfairnesscode import data, losses, optimization, model, utils, dro_training, softweights_training
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
# Out:
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
import traceback

# %%
def writejson(path,arr,name):
    try:
        os.mkdir(path+'preds/')
    except:
        pass
    f = open(path+'preds/'+name,'w')
    json.dump(arr,f)
    f.close()

# %%
path = 'data/datasets/law_school/'
synthfols = glob("data/datasets/law_school/synthetic/*/")
paths = [path]
paths.extend(synthfols)

# %%
def task(path):
    
    print(path)

    if True:#os.path.exists(path+'preds/Softweights_pred.json') == False:
        
        train_df = pd.read_csv(path+'train.csv',header=None)

        train_df.columns = ['zfygpa', 'zgpa', 'DOB_yr', 'weighted_lsat_ugpa', 'cluster_tier',
       'family_income', 'lsat', 'ugpa', 'isPartTime', 'sex', 'race',
       'pass_bar']



#         train_df.index = train_df['SEX']

#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})


        train_df = train_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

        test_df = pd.read_csv(path+'test.csv',header=None)

        test_df.columns = ['zfygpa', 'zgpa', 'DOB_yr', 'weighted_lsat_ugpa', 'cluster_tier',
       'family_income', 'lsat', 'ugpa', 'isPartTime', 'sex', 'race',
       'pass_bar']


#         test_df.index = test_df['SEX']
        
#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})

        

        X_train = train_df.drop(['pass_bar'],axis=1)
        X_test = test_df.drop(['pass_bar'],axis=1)

        Y_train = pd.Series(train_df['pass_bar'])
        Y_test = pd.Series(test_df['pass_bar'])

        Y_train = pd.Series(Y_train.factorize(sort=True)[0], index=Y_train.index)
        Y_test = pd.Series(Y_test.factorize(sort=True)[0], index=Y_test.index)

        X_merged = pd.concat([X_train,X_test])

        ohe = make_column_transformer(
            (OneHotEncoder(sparse=False), X_merged.dtypes == 'object'),
            remainder='passthrough', verbose_feature_names_out=False)

        X_merged_temp  = pd.DataFrame(ohe.fit_transform(X_merged), columns=ohe.get_feature_names_out(), index=X_merged.index)

        train_df  = pd.DataFrame(ohe.transform(X_train), columns=ohe.get_feature_names_out(), index=X_train.index)
        test_df = pd.DataFrame(ohe.transform(X_test), columns=ohe.get_feature_names_out(), index=X_test.index)
        
        train_df['pass_bar'] = Y_train
        test_df['pass_bar'] = Y_test

        print(train_df.columns)

        LABEL_COLUMN = "pass_bar"
        FEATURE_NAMES = list(train_df.columns)
        FEATURE_NAMES.remove(LABEL_COLUMN)
        PROTECTED_COLUMNS = ['sex_Female','sex_Male']

        PROXY_COLUMNS = PROTECTED_COLUMNS 


        val,_,_,_ = dro_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                          PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 1,constraint='tpr_and_fpr')

        vall = [float(v) for v in val[0]]

        val_m = [0 if i < 0 else 1 for i in vall]

        writejson(path,val_m,'DRO_pred.json')

        val2,_,_,_ = softweights_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                                   PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 1, constraint='tpr_and_fpr')

        val2l = [float(v) for v in val2[0]]

        val_m2 = [0 if i < 0 else 1 for i in val2l]

        writejson(path,val_m2,'Softweights_pred.json')

        return path, 'DRO and SW done'

# %%
import random
random.shuffle(paths)
for path in paths:
    try:
        task(path)
    except:
        traceback.print_exc()
# Out:
# data/datasets/law_school/synthetic/gender_flip_labels0.9_version7/
# Index(['isPartTime_No', 'isPartTime_Yes', 'sex_Female', 'sex_Male',
#        'race_Black', 'race_Other', 'race_White', 'zfygpa', 'zgpa', 'DOB_yr',
#        'weighted_lsat_ugpa', 'cluster_tier', 'family_income', 'lsat', 'ugpa',
#        'pass_bar'],
#       dtype='object')
# Split 1 of 1
# time since start: 0.03332233428955078
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:70: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5518790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5518790>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5518790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5518790>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:85: The name tf.losses.hinge_loss is deprecated. Please use tf.compat.v1.losses.hinge_loss instead.
#
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:157: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# minibatch is off
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:169: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5733981132507324
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 5.995024681091309
# time since start: 6.02881646156311
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e01f6410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e01f6410>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e01f6410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e01f6410>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4564242362976074
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 5.734818696975708
# time since start: 11.764072179794312
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e07c3a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e07c3a10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e07c3a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e07c3a10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.492264747619629
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 5.833018779754639
# time since start: 17.597530841827393
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0e05490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0e05490>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0e05490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0e05490>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4818987846374512
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 5.752206563949585
# time since start: 23.349767684936523
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00708d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00708d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00708d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00708d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.559523582458496
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 5.816977500915527
# time since start: 29.1671884059906
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e08c3810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e08c3810>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e08c3810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e08c3810>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5121827125549316
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# Time that this run took: 5.86023473739624
# time since start: 35.02786684036255
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0dbf6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0dbf6d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0dbf6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0dbf6d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4825193881988525
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# Time that this run took: 5.756876707077026
# time since start: 40.784767150878906
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c005b350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c005b350>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c005b350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c005b350>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5167829990386963
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# Time that this run took: 5.858231067657471
# time since start: 46.643441677093506
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37d81f3890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37d81f3890>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37d81f3890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37d81f3890>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5501387119293213
# tpr_overall 1.0
# fpr_overall 0.9995551601423488
# tpr_overall 0.9998781230956734
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# Time that this run took: 5.81703782081604
# time since start: 52.460957765579224
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09b5dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09b5dd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09b5dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09b5dd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.550755262374878
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# Time that this run took: 5.914135217666626
# time since start: 58.37553596496582
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1358bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1358bd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1358bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1358bd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4895617961883545
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# Time that this run took: 5.781016111373901
# time since start: 64.15670347213745
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0c61110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0c61110>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0c61110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0c61110>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4991459846496582
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# Time that this run took: 5.778090000152588
# time since start: 69.93524098396301
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00aa150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00aa150>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00aa150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00aa150>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.501091480255127
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 5.8518385887146
# time since start: 75.78752851486206
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e02e5b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e02e5b10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e02e5b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e02e5b10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5383994579315186
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 5.860840320587158
# time since start: 81.64883756637573
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c05a0f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c05a0f10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c05a0f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c05a0f10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.520822286605835
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 5.8851237297058105
# time since start: 87.53418755531311
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00859d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00859d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00859d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c00859d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5032870769500732
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 5.779481887817383
# time since start: 93.31411576271057
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09dbc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09dbc50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09dbc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09dbc50>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5204269886016846
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 5.8875038623809814
# time since start: 99.20206022262573
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3790>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3790>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5261943340301514
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# Time that this run took: 5.833771467208862
# time since start: 105.0362811088562
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecfed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecfed0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecfed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecfed0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4942352771759033
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# Time that this run took: 5.753979682922363
# time since start: 110.79048371315002
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0452b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0452b10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0452b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0452b10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5032658576965332
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# Time that this run took: 5.8436760902404785
# time since start: 116.63460111618042
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06fda50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06fda50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06fda50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06fda50>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5045971870422363
# tpr_overall 0.9998863248834831
# fpr_overall 0.9995551601423488
# tpr_overall 0.9998781230956734
# fpr_overall 0.9994977398292315
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# Time that this run took: 5.78144097328186
# time since start: 122.4164810180664
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7bb410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7bb410>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7bb410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7bb410>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.525865077972412
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# Time that this run took: 5.892215967178345
# time since start: 128.30913734436035
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3190>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3190>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3190>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c7f3190>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.560774803161621
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# Time that this run took: 5.895468235015869
# time since start: 134.20463705062866
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecf590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecf590>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecf590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1ecf590>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5286531448364258
# tpr_overall 0.9281573263612595
# fpr_overall 0.9684163701067615
# tpr_overall 0.9258988421694089
# fpr_overall 0.9663485685585133
# tpr_overall 0.9221753398968588
# fpr_overall 0.9722222222222222
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# Time that this run took: 5.846761703491211
# time since start: 140.05159854888916
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06da390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06da390>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06da390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e06da390>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.520597219467163
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 5.915369272232056
# time since start: 145.96741366386414
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300790>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300790>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5192761421203613
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 5.819816589355469
# time since start: 151.78766894340515
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0181b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0181b10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0181b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0181b10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5007388591766357
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 5.866818428039551
# time since start: 157.65492916107178
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0ff89d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0ff89d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0ff89d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e0ff89d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.518362283706665
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 5.807338237762451
# time since start: 163.46270489692688
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e05eb150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e05eb150>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e05eb150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e05eb150>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.4969120025634766
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 5.865050315856934
# time since start: 169.32778978347778
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e083a7d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e083a7d0>>: AttributeError: module 'gast' has no attribute 'Index'
# ...
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e03e4dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e03e4dd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.552243947982788
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# Time that this run took: 5.919266223907471
# time since start: 110.97869491577148
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f375c7734d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f375c7734d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f375c7734d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f375c7734d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.523418664932251
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# Time that this run took: 5.842005491256714
# time since start: 116.82115340232849
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0468910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0468910>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0468910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37c0468910>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.504645824432373
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# tpr_overall 0.0
# fpr_overall 0.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# Time that this run took: 5.87963604927063
# time since start: 122.70167851448059
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09c36d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09c36d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09c36d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e09c36d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5088591575622559
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# Time that this run took: 5.7915778160095215
# time since start: 128.4937047958374
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5947590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5947590>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5947590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5947590>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5605640411376953
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# Time that this run took: 5.934282541275024
# time since start: 134.42843389511108
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e12b1090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e12b1090>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e12b1090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e12b1090>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5320696830749512
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# Time that this run took: 5.824908018112183
# time since start: 140.253812789917
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e063ea50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e063ea50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e063ea50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e063ea50>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5060181617736816
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 5.784307479858398
# time since start: 146.03857445716858
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5905710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5905710>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5905710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e5905710>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5044310092926025
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 5.861478090286255
# time since start: 151.90050530433655
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c26a950>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c26a950>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c26a950>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f379c26a950>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5401275157928467
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 5.8392417430877686
# time since start: 157.7397871017456
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300690>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e1300690>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.512800931930542
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 5.91516900062561
# time since start: 163.65540862083435
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00709d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00709d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00709d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f37e00709d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  1.5306224822998047
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0

# %%
# from multiprocessing.pool import ThreadPool as Pool

# pool = Pool(10)
# for result in pool.imap_unordered(task, paths):
#     print(result)

# %%
#   Args:
#     predictions: numpy array of floats representing predictions. Predictions are treated 
#       as positive classification if value is >0, and negative classification if value is <= 0.
#     labels: numpy array of floats representing labels. labels are also treated as positive 
#       classification if value is >0, and negative classification if value is <= 0.
