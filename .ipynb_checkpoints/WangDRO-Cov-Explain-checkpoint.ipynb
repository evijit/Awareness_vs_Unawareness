# %%
import os,sys,json
from glob import glob

os.chdir('/home/avijit/projects/Awareness_vs_Unawareness')
sys.path.insert(0,"/home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode")

# %%
import warnings
warnings.filterwarnings('ignore')

from robustfairnesscode import data, losses, optimization, model, utils, dro_training, softweights_training
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
# Out:
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
def writejson(path,arr,name):
    try:
        os.mkdir(path+'preds/')
    except:
        pass
    f = open(path+'preds/'+name,'w')
    json.dump(arr,f)
    f.close()

# %%
path = 'data/datasets/publiccov/'
synthfols = glob("data/datasets/publiccov/synthetic/*/")
paths = [path]
paths.extend(synthfols)

# %%
def task(path):
    
    print(path)

    if os.path.exists(path+'preds/Softweights_pred.json') == False:
        
        train_df = pd.read_csv(path+'train.csv',header=None)

        train_df.columns = ['AGEP', 'SCHL', 'MAR', 'SEX', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
           'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'PINCP', 'ESR', 'FER', 'RAC1P',
           'PUBCOV']


#         train_df.index = train_df['SEX']

#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})


        train_df = train_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

        test_df = pd.read_csv(path+'test.csv',header=None)

        test_df.columns = ['AGEP', 'SCHL', 'MAR', 'SEX', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
           'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'PINCP', 'ESR', 'FER', 'RAC1P',
           'PUBCOV']


#         test_df.index = test_df['SEX']
        
#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})

        

        X_train = train_df.drop(['PUBCOV'],axis=1)
        X_test = test_df.drop(['PUBCOV'],axis=1)

        Y_train = pd.Series(train_df['PUBCOV'])
        Y_test = pd.Series(test_df['PUBCOV'])

        Y_train = pd.Series(Y_train.factorize(sort=True)[0], index=Y_train.index)
        Y_test = pd.Series(Y_test.factorize(sort=True)[0], index=Y_test.index)

        X_merged = pd.concat([X_train,X_test])

        ohe = make_column_transformer(
            (OneHotEncoder(sparse=False), X_merged.dtypes == 'object'),
            remainder='passthrough', verbose_feature_names_out=False)

        X_merged_temp  = pd.DataFrame(ohe.fit_transform(X_merged), columns=ohe.get_feature_names_out(), index=X_merged.index)

        train_df  = pd.DataFrame(ohe.transform(X_train), columns=ohe.get_feature_names_out(), index=X_train.index)
        test_df = pd.DataFrame(ohe.transform(X_test), columns=ohe.get_feature_names_out(), index=X_test.index)
        
        train_df['PUBCOV'] = Y_train
        test_df['PUBCOV'] = Y_test

        print(train_df.columns)

        LABEL_COLUMN = "PUBCOV"
        FEATURE_NAMES = list(train_df.columns)
        FEATURE_NAMES.remove(LABEL_COLUMN)
        PROTECTED_COLUMNS = ['SEX_Female','SEX_Male']

        PROXY_COLUMNS = PROTECTED_COLUMNS 


        val = dro_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                          PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10,constraint='tpr_and_fpr')

        vall = [float(v) for v in val[0]]

        val_m = [0 if i < 0 else 1 for i in vall]

        writejson(path,val_m,'DRO_pred.json')

        val2 = softweights_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                                   PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10, constraint='tpr_and_fpr')

        val2l = [float(v) for v in val2[0]]

        val_m2 = [0 if i < 0 else 1 for i in val2l]

        writejson(path,val_m2,'Softweights_pred.json')

        return path, 'DRO and SW done'

# %%
import random
random.shuffle(paths)
for path in paths:
    try:
        task(path)
    except:
        traceback.print_exc()
# Out:
# data/datasets/publiccov/synthetic/gender_flip_labels0.4_version3/
# data/datasets/publiccov/synthetic/gender_flip_labels0.6_version0/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version5/
# data/datasets/publiccov/synthetic/gender_flip_labels0.8_version5/
# data/datasets/publiccov/synthetic/gender_flip_labels0.8_version7/
# Index(['SCHL_1 or more years of college credit, no degree',
#        'SCHL_12th grade - no diploma', 'SCHL_Associate's degree',
#        'SCHL_Bachelor's degree', 'SCHL_Doctorate degree',
#        'SCHL_GED or alternative credential', 'SCHL_Grade 1', 'SCHL_Grade 10',
#        'SCHL_Grade 11', 'SCHL_Grade 2', 'SCHL_Grade 3', 'SCHL_Grade 4',
#        'SCHL_Grade 5', 'SCHL_Grade 6', 'SCHL_Grade 7', 'SCHL_Grade 8',
#        'SCHL_Grade 9', 'SCHL_Kindergarten', 'SCHL_Master's degree',
#        'SCHL_No schooling completed', 'SCHL_Nursery school, preschool',
#        'SCHL_Professional degree beyond a bachelor's degree',
#        'SCHL_Regular high school diploma',
#        'SCHL_Some college, but less than 1 year', 'MAR_Divorced',
#        'MAR_Married', 'MAR_Never married or under 15 years old',
#        'MAR_Separated', 'MAR_Widowed', 'SEX_Female', 'SEX_Male',
#        'DIS_With a disability', 'DIS_Without a disability',
#        'ESP_Both parents in labor force', 'ESP_Father in the labor force',
#        'ESP_Father not in labor force living with mother:',
#        'ESP_Father only in labor force', 'ESP_Mother in the labor force',
#        'ESP_Mother not in labor force', 'ESP_Mother only in labor force',
#        'ESP_N/A (not own child of householder, and not child in subfamily) Living with two parents:',
#        'ESP_Neither parent in labor force living with one parent: Living with father:',
#        'CIT_Born abroad of American parent(s)',
#        'CIT_Born in Puerto Rico, Guam, the U.S. Virgin Islands, or the Northern Marianas',
#        'CIT_Born in the U.S.', 'CIT_Not a citizen of the U.S.',
#        'CIT_U.S. citizen by naturalization',
#        'MIG_No, different house in US or Puerto Rico',
#        'MIG_No, outside US and Puerto Rico', 'MIG_Yes, same house (nonmovers)',
#        'MIL_N/A (less than 17 years old)', 'MIL_Never served in the military',
#        'MIL_Now on active duty', 'MIL_On active duty in the past, but not now',
#        'MIL_Only on active duty for training in Reserves/National Guard',
#        'ANC_Multiple', 'ANC_Not reported', 'ANC_Single', 'ANC_Unclassified',
#        'NATIVITY_Foreign born', 'NATIVITY_Native', 'DEAR_No', 'DEAR_Yes',
#        'DEYE_No', 'DEYE_Yes', 'DREM_No', 'DREM_Yes',
#        'ESR_Armed forces, at work',
#        'ESR_Armed forces, with a job but not at work',
#        'ESR_Civilian employed, at work',
#        'ESR_Civilian employed, with a job but not at work',
#        'ESR_N/A (less than 16 years old)', 'ESR_Not in labor force',
#        'ESR_Unemployed',
#        'FER_N/A (less than 15 years/greater than 50 years/ male)', 'FER_No',
#        'FER_Yes', 'RAC1P_Alaska', 'RAC1P_American', 'RAC1P_Asian',
#        'RAC1P_Black', 'RAC1P_Native', 'RAC1P_Some', 'RAC1P_Two', 'RAC1P_White',
#        'AGEP', 'PINCP', 'PUBCOV'],
#       dtype='object')
# Split 1 of 1
# time since start: 0.21036720275878906
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:70: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd7033d8590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd7033d8590>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd7033d8590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd7033d8590>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:85: The name tf.losses.hinge_loss is deprecated. Please use tf.compat.v1.losses.hinge_loss instead.
#
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:157: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# minibatch is off
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:169: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  5.2199866771698
# tpr_overall 0.007426436244745446
# fpr_overall 0.00797725516175334
# tpr_overall 0.006253203485392106
# fpr_overall 0.007300786466834842
# tpr_overall 0.007451710952054123
# fpr_overall 0.006681132937414344
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.810096502304077
# tpr_overall 0.08262494161606726
# fpr_overall 0.08449265761289611
# tpr_overall 0.08344438749359302
# fpr_overall 0.08164416085472621
# tpr_overall 0.08147857633101284
# fpr_overall 0.08445637277295569
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.997288703918457
# tpr_overall 0.2319943951424568
# fpr_overall 0.2505796621397814
# tpr_overall 0.2311122501281394
# fpr_overall 0.24757382400949696
# tpr_overall 0.22884596529071477
# fpr_overall 0.24617405207857468
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.3690574169158936
# tpr_overall 0.32503503035964504
# fpr_overall 0.3308214640609473
# tpr_overall 0.32091235263967194
# fpr_overall 0.32856506900133553
# tpr_overall 0.32532601235415237
# fpr_overall 0.3269757880310644
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.946808099746704
# tpr_overall 0.3305464736104624
# fpr_overall 0.3330020978248868
# tpr_overall 0.32619169656586366
# fpr_overall 0.3311767324528862
# tpr_overall 0.3321894303363075
# fpr_overall 0.32891731384193695
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  4.100841522216797
# tpr_overall 0.33423633815973847
# fpr_overall 0.3375289831069891
# tpr_overall 0.33024090210148643
# fpr_overall 0.33556907553049414
# tpr_overall 0.33630748112560055
# fpr_overall 0.33342850616719966
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  4.186514139175415
# tpr_overall 0.9973843998131714
# fpr_overall 0.9964116153251629
# tpr_overall 0.9974884674525885
# fpr_overall 0.9970322006232378
# tpr_overall 0.997254632807138
# fpr_overall 0.9972590223846505
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.5960237979888916
# tpr_overall 0.21980382998598785
# fpr_overall 0.23721982996577234
# tpr_overall 0.22070732957457714
# fpr_overall 0.23347677696987684
# tpr_overall 0.2193352289440141
# fpr_overall 0.2310986751941526
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  4.194016695022583
# tpr_overall 0.13190098085007007
# fpr_overall 0.13967097272827647
# tpr_overall 0.13090722706304458
# fpr_overall 0.13812138299450957
# tpr_overall 0.13207177174232768
# fpr_overall 0.14024668798538145
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  4.1382012367248535
# tpr_overall 0.08070994862213919
# fpr_overall 0.08620404107320305
# tpr_overall 0.07883136852895951
# fpr_overall 0.08568036800712271
# tpr_overall 0.0787332091381508
# fpr_overall 0.08776838739150297
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 203.77753901481628
# time since start: 203.9879388809204
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6feedef90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6feedef90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6feedef90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6feedef90>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.970776081085205
# tpr_overall 0.006679121905651565
# fpr_overall 0.00728718118582312
# tpr_overall 0.005279343926191697
# fpr_overall 0.00658851461641193
# tpr_overall 0.006765369153838611
# fpr_overall 0.006110095934216537
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  4.23298716545105
# tpr_overall 0.09327417094815507
# fpr_overall 0.09818372529535166
# tpr_overall 0.0946694003075346
# fpr_overall 0.09461344413117673
# tpr_overall 0.09510736346700657
# fpr_overall 0.09759022384650526
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  4.147639036178589
# tpr_overall 0.2829518916394208
# fpr_overall 0.2984983990283758
# tpr_overall 0.28088159917990774
# fpr_overall 0.2981748033832913
# tpr_overall 0.2830669673497402
# fpr_overall 0.2961968935587026
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.688782215118408
# tpr_overall 0.3300794021485287
# fpr_overall 0.3325880534393287
# tpr_overall 0.3259866735007688
# fpr_overall 0.3305238165899985
# tpr_overall 0.33199333267967446
# fpr_overall 0.3283462768387391
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.9340169429779053
# tpr_overall 0.3309201307800093
# fpr_overall 0.3336093629237054
# tpr_overall 0.32680676576114814
# fpr_overall 0.33179997032200625
# tpr_overall 0.33267967447789
# fpr_overall 0.3297167656464139
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.7129993438720703
# tpr_overall 0.3309668379262027
# fpr_overall 0.33380258363696585
# tpr_overall 0.32696053305996925
# fpr_overall 0.3319186822970767
# tpr_overall 0.33267967447789
# fpr_overall 0.33005938784833255
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  4.006784915924072
# tpr_overall 0.3309201307800093
# fpr_overall 0.33374737771889146
# tpr_overall 0.32696053305996925
# fpr_overall 0.3317702923282386
# tpr_overall 0.3325816256495735
# fpr_overall 0.329945180447693
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.5080862045288086
# tpr_overall 0.334049509574965
# fpr_overall 0.3372253505575798
# tpr_overall 0.3298821117375705
# fpr_overall 0.33515358361774744
# tpr_overall 0.33591528581233454
# fpr_overall 0.3329716765646414
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  4.220112323760986
# tpr_overall 0.9985520784680056
# fpr_overall 0.9967980567516838
# tpr_overall 0.9985135827780626
# fpr_overall 0.9973883365484493
# tpr_overall 0.998823414060202
# fpr_overall 0.9975445408862494
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.1362130641937256
# tpr_overall 0.3279775805698272
# fpr_overall 0.33267086231644033
# tpr_overall 0.3247565351101999
# fpr_overall 0.3318890043033091
# tpr_overall 0.3291499166584959
# fpr_overall 0.330459113750571
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 201.55351567268372
# time since start: 405.5416810512543
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e8301510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e8301510>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e8301510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e8301510>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  3.9687650203704834
# tpr_overall 0.006258757589911256
# fpr_overall 0.0069835486364138236
# tpr_overall 0.005125576627370579
# fpr_overall 0.006262056684968096
# tpr_overall 0.0060790273556231
# fpr_overall 0.005881681132937414
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.0180346965789795
# tpr_overall 0.09084539934609995
# fpr_overall 0.09503698796510986
# tpr_overall 0.09210661199384931
# fpr_overall 0.09182371271702033
# tpr_overall 0.09059711736444749
# fpr_overall 0.09393558702603928
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.0376040935516357
# tpr_overall 0.28248482017748716
# fpr_overall 0.2986640167825991
# tpr_overall 0.280317785750897
# fpr_overall 0.2981154473957561
# tpr_overall 0.28198843023825865
# fpr_overall 0.2966537231612609
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.037125825881958
# tpr_overall 0.3302195235871088
# fpr_overall 0.3327536711935519
# tpr_overall 0.32603792926704256
# fpr_overall 0.3307612405401395
# tpr_overall 0.33199333267967446
# fpr_overall 0.3285175879396985
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.0442352294921875
# tpr_overall 0.3322279308734236
# fpr_overall 0.335403555261124
# tpr_overall 0.32844695028190674
# fpr_overall 0.33343225997922543
# tpr_overall 0.3339543092460045
# fpr_overall 0.331772498857926
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.015687942504883
# tpr_overall 0.3333956095282578
# fpr_overall 0.33681130617202165
# tpr_overall 0.32962583290620195
# fpr_overall 0.33491615966760646
# tpr_overall 0.33552309049906853
# fpr_overall 0.33268615806304247
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.0267696380615234
# tpr_overall 0.3341896310135451
# fpr_overall 0.3375565860660263
# tpr_overall 0.3299846232701179
# fpr_overall 0.3354503635554237
# tpr_overall 0.33620943229728406
# fpr_overall 0.3332571950662403
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.0050201416015625
# tpr_overall 0.9999532928538066
# fpr_overall 0.9999447940819256
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.048847198486328
# tpr_overall 0.31027557216254087
# fpr_overall 0.32933090427293804
# tpr_overall 0.3070732957457714
# fpr_overall 0.32832764505119455
# tpr_overall 0.31248161584469064
# fpr_overall 0.3264047510278666
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.171473741531372
# tpr_overall 0.14908921064922934
# fpr_overall 0.172132052556034
# tpr_overall 0.14838544336237827
# fpr_overall 0.1710342780828016
# tpr_overall 0.1455044612216884
# fpr_overall 0.1715395157606213
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 192.59821248054504
# time since start: 598.1399259567261
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff023e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff023e90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff023e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff023e90>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  3.925567150115967
# tpr_overall 0.0061186361513311536
# fpr_overall 0.006790327923153362
# tpr_overall 0.004971809328549462
# fpr_overall 0.006054310728594747
# tpr_overall 0.005882929698990097
# fpr_overall 0.005767473732297853
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.0900497436523438
# tpr_overall 0.08766931340495096
# fpr_overall 0.09136579441316109
# tpr_overall 0.08913377754997437
# fpr_overall 0.08852945540881436
# tpr_overall 0.08677321306010394
# fpr_overall 0.09039515760621289
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.046504259109497
# tpr_overall 0.2811303129378795
# fpr_overall 0.2968698244451805
# tpr_overall 0.278575089697591
# fpr_overall 0.2968986496512836
# tpr_overall 0.28100794195509365
# fpr_overall 0.29494061215166745
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.1111302375793457
# tpr_overall 0.3302195235871088
# fpr_overall 0.3327536711935519
# tpr_overall 0.32603792926704256
# fpr_overall 0.33070188455260424
# tpr_overall 0.33199333267967446
# fpr_overall 0.3285175879396985
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.08550763130188
# tpr_overall 0.3317141522652966
# fpr_overall 0.33515512862978913
# tpr_overall 0.3279343926191697
# fpr_overall 0.3329870900727111
# tpr_overall 0.333267967447789
# fpr_overall 0.33125856555504796
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.0563013553619385
# tpr_overall 0.3325548808967772
# fpr_overall 0.33567958485149607
# tpr_overall 0.3286519733470015
# fpr_overall 0.33361032794183115
# tpr_overall 0.3343465045592705
# fpr_overall 0.33194380995888534
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.023613214492798
# tpr_overall 0.33246146660439047
# fpr_overall 0.3358452026057193
# tpr_overall 0.3286519733470015
# fpr_overall 0.3335806499480635
# tpr_overall 0.3343465045592705
# fpr_overall 0.33200091365920514
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.038257598876953
# tpr_overall 0.9983652498832322
# fpr_overall 0.9966600419564977
# tpr_overall 0.9984110712455151
# fpr_overall 0.9972696245733789
# tpr_overall 0.9985292675752525
# fpr_overall 0.9975445408862494
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.0608956813812256
# tpr_overall 0.3050910789350771
# fpr_overall 0.32563210776195206
# tpr_overall 0.30199897488467453
# fpr_overall 0.3252411336993619
# tpr_overall 0.30581429551916856
# fpr_overall 0.3236637734125171
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.2102441787719727
# tpr_overall 0.13886034563288183
# fpr_overall 0.16001435353869936
# tpr_overall 0.137109174782163
# fpr_overall 0.157916604837513
# tpr_overall 0.1339346994803412
# fpr_overall 0.15989036089538602
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 193.3461399078369
# time since start: 791.4862854480743
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff32e710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff32e710>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff32e710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff32e710>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.363786697387695
# tpr_overall 0.9983652498832322
# fpr_overall 0.9966324389974606
# tpr_overall 0.9982060481804202
# fpr_overall 0.9971509125983083
# tpr_overall 0.9985292675752525
# fpr_overall 0.9974874371859297
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.505310297012329
# tpr_overall 0.06936011209715086
# fpr_overall 0.06638511648448714
# tpr_overall 0.0699128651973347
# fpr_overall 0.06380768660038581
# tpr_overall 0.0720658888126287
# fpr_overall 0.0657834627683874
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.0602564811706543
# tpr_overall 0.010088743577767399
# fpr_overall 0.009026167605167274
# tpr_overall 0.00999487442337263
# fpr_overall 0.008903398130286393
# tpr_overall 0.008334150406902637
# fpr_overall 0.009079488350845134
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.0130019187927246
# tpr_overall 0.05441382531527324
# fpr_overall 0.04717345699458982
# tpr_overall 0.055099948744233726
# fpr_overall 0.04629767027748924
# tpr_overall 0.05294636729091087
# fpr_overall 0.047396071265418
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.964231491088867
# tpr_overall 0.023353573096683792
# fpr_overall 0.017224246439218285
# tpr_overall 0.022193746796514608
# fpr_overall 0.01748033832912895
# tpr_overall 0.022453181684478872
# fpr_overall 0.017816354499771585
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.0552589893341064
# tpr_overall 0.020597851471275106
# fpr_overall 0.014629568289720658
# tpr_overall 0.021117375704766787
# fpr_overall 0.014868674877578276
# tpr_overall 0.020884400431414846
# fpr_overall 0.014390132480584742
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.2510287761688232
# tpr_overall 0.015226529659037832
# fpr_overall 0.010047477089544
# tpr_overall 0.015325474115838032
# fpr_overall 0.00997180590592076
# tpr_overall 0.01588391018727326
# fpr_overall 0.009936043855641846
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.0875182151794434
# tpr_overall 0.045305931807566556
# fpr_overall 0.023131279673180963
# tpr_overall 0.04433623782675551
# fpr_overall 0.02237720730078647
# tpr_overall 0.04382782625747622
# fpr_overall 0.023698035632709
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.2575740814208984
# tpr_overall 0.043764595983185425
# fpr_overall 0.020288174892348458
# tpr_overall 0.04315735520246028
# fpr_overall 0.019765543849235793
# tpr_overall 0.042259045004412195
# fpr_overall 0.020043398812243034
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.1611838340759277
# tpr_overall 0.11433909388136385
# fpr_overall 0.056641271944352437
# tpr_overall 0.11266017426960533
# fpr_overall 0.05846564772221398
# tpr_overall 0.1154034709285224
# fpr_overall 0.05527638190954774
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 193.95841240882874
# time since start: 985.444727897644
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fef59590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fef59590>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fef59590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fef59590>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.1581056118011475
# tpr_overall 0.9983185427370388
# fpr_overall 0.9966048360384233
# tpr_overall 0.9982060481804202
# fpr_overall 0.9971509125983083
# tpr_overall 0.9985292675752525
# fpr_overall 0.9974874371859297
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.2193820476531982
# tpr_overall 0.6678187762727698
# fpr_overall 0.6647620624930992
# tpr_overall 0.6714505381855459
# fpr_overall 0.6672503338774299
# tpr_overall 0.6658495930973625
# fpr_overall 0.6690840566468708
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.218247890472412
# tpr_overall 0.662260625875759
# fpr_overall 0.660235177210997
# tpr_overall 0.6665299846232701
# fpr_overall 0.6626502448434486
# tpr_overall 0.6606530051965879
# fpr_overall 0.664572864321608
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.0351154804229736
# tpr_overall 0.6665576833255488
# fpr_overall 0.662747046483383
# tpr_overall 0.6698103536647873
# fpr_overall 0.6650838403323935
# tpr_overall 0.6644769095009314
# fpr_overall 0.6668570123343993
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.554882049560547
# tpr_overall 0.001588042970574498
# fpr_overall 0.0033399580435022635
# tpr_overall 0.0015889287544848796
# fpr_overall 0.0027600534203887817
# tpr_overall 0.0013726835964310226
# fpr_overall 0.002455459113750571
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.246699333190918
# tpr_overall 0.2465203176085941
# fpr_overall 0.3540355526112399
# tpr_overall 0.24818042029728343
# fpr_overall 0.3594301825196617
# tpr_overall 0.2488479262672811
# fpr_overall 0.3613522156235724
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.297247886657715
# tpr_overall 0.36576366184026154
# fpr_overall 0.44744396599315445
# tpr_overall 0.37114300358790364
# fpr_overall 0.45255972696245733
# tpr_overall 0.3687616432983626
# fpr_overall 0.45460255824577434
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.271876811981201
# tpr_overall 0.5723960765997198
# fpr_overall 0.5825328475212542
# tpr_overall 0.5801640184520759
# fpr_overall 0.5831428995399911
# tpr_overall 0.5716246690852045
# fpr_overall 0.5848560986751942
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.6639134883880615
# tpr_overall 0.5916861279775806
# fpr_overall 0.5978800927459423
# tpr_overall 0.5970271655561251
# fpr_overall 0.5982489983677104
# tpr_overall 0.5902539464653397
# fpr_overall 0.6015874828688899
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.2625908851623535
# tpr_overall 0.000560485754320411
# fpr_overall 0.0009661035663023076
# tpr_overall 0.0006663249615581752
# fpr_overall 0.0010980857694019885
# tpr_overall 0.0003921953132660065
# fpr_overall 0.0006852444038373687
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# Time that this run took: 195.35422563552856
# time since start: 1180.7989897727966
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff3a7b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff3a7b10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff3a7b10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6ff3a7b10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  3.8277251720428467
# tpr_overall 0.9983185427370388
# fpr_overall 0.9966048360384233
# tpr_overall 0.9982060481804202
# fpr_overall 0.9971509125983083
# tpr_overall 0.9985292675752525
# fpr_overall 0.9974874371859297
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  2.972414493560791
# tpr_overall 0.6688930406352172
# fpr_overall 0.6658385778955505
# tpr_overall 0.6724243977447463
# fpr_overall 0.6676658257901766
# tpr_overall 0.6666339837238945
# fpr_overall 0.6701690269529466
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  2.9565560817718506
# tpr_overall 0.6567024754787483
# fpr_overall 0.6567572043723087
# tpr_overall 0.6613531522296259
# fpr_overall 0.6587624276598902
# tpr_overall 0.6556525149524464
# fpr_overall 0.6602329830973047
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  2.950516700744629
# tpr_overall 0.6612330686595049
# fpr_overall 0.6589654410952854
# tpr_overall 0.6654536135315223
# fpr_overall 0.6612553791363703
# tpr_overall 0.6597705657417394
# fpr_overall 0.663544997715852
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.897181749343872
# tpr_overall 0.001681457262961233
# fpr_overall 0.003395163961576681
# tpr_overall 0.0017939518195797027
# fpr_overall 0.002878765395459267
# tpr_overall 0.0014707324247475242
# fpr_overall 0.002512562814070352
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  2.8200714588165283
# tpr_overall 0.02494161606725829
# fpr_overall 0.01738986419344154
# tpr_overall 0.02670425422860072
# fpr_overall 0.01771776227926992
# tpr_overall 0.026179037160505934
# fpr_overall 0.017645043398812243
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  2.8597710132598877
# tpr_overall 0.9612797758056982
# fpr_overall 0.9518880423981451
# tpr_overall 0.9585853408508457
# fpr_overall 0.9532868378097641
# tpr_overall 0.9569565643690557
# fpr_overall 0.9531749657377798
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  2.830798387527466
# tpr_overall 0.32312003736571693
# fpr_overall 0.31884177983879874
# tpr_overall 0.31998974884674525
# fpr_overall 0.31817777118266805
# tpr_overall 0.32356113344445536
# fpr_overall 0.31681132937414347
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  2.842531681060791
# tpr_overall 0.35628211116300795
# fpr_overall 0.3540907585293143
# tpr_overall 0.35269092772936955
# fpr_overall 0.3518326161151506
# tpr_overall 0.3583684674968134
# fpr_overall 0.35055961626313387
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.194018602371216
# tpr_overall 0.34128911723493693
# fpr_overall 0.3423318979794634
# tpr_overall 0.3377754997437212
# fpr_overall 0.33993174061433445
# tpr_overall 0.34317089910775567
# fpr_overall 0.3386249428962997
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# Time that this run took: 191.52004718780518
# time since start: 1372.3190655708313
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fee11f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fee11f10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fee11f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fee11f10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.153182029724121
# tpr_overall 0.9978981784212985
# fpr_overall 0.9965220271613117
# tpr_overall 0.997898513582778
# fpr_overall 0.9970915566107731
# tpr_overall 0.9981370722619864
# fpr_overall 0.9973732297852901
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.229154109954834
# tpr_overall 0.664175618869687
# fpr_overall 0.6620569725074528
# tpr_overall 0.6684264479753972
# fpr_overall 0.6642231785131325
# tpr_overall 0.6625159329346014
# fpr_overall 0.6659433531292828
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.1994521617889404
# tpr_overall 0.6624007473143391
# fpr_overall 0.6604836038423318
# tpr_overall 0.6667350076883649
# fpr_overall 0.6628579907998219
# tpr_overall 0.6608491028532208
# fpr_overall 0.6649154865235267
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.3132081031799316
# tpr_overall 0.665436711816908
# fpr_overall 0.6627194435243459
# tpr_overall 0.6696053305996925
# fpr_overall 0.6648760943760201
# tpr_overall 0.6634964212177664
# fpr_overall 0.6665714938328003
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.55609393119812
# tpr_overall 0.6573096683792621
# fpr_overall 0.6568676162084576
# tpr_overall 0.6620707329574577
# fpr_overall 0.6585546817035168
# tpr_overall 0.6562408079223453
# fpr_overall 0.6606898126998629
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.2484583854675293
# tpr_overall 0.6553479682391405
# fpr_overall 0.655211438666225
# tpr_overall 0.6599179907739621
# fpr_overall 0.6574862739278825
# tpr_overall 0.6539856848710658
# fpr_overall 0.6592622201918684
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.241734266281128
# tpr_overall 0.6580569827183559
# fpr_overall 0.6573092635530529
# tpr_overall 0.6630445925166581
# fpr_overall 0.6594153435227779
# tpr_overall 0.6570251985488773
# fpr_overall 0.6614892645043399
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.2790606021881104
# tpr_overall 0.6530126109294722
# fpr_overall 0.65308601082036
# tpr_overall 0.6571501793951819
# fpr_overall 0.6554384923579166
# tpr_overall 0.6506520247083047
# fpr_overall 0.6568067610781179
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.2325243949890137
# tpr_overall 0.6448388603456329
# fpr_overall 0.6468477420779507
# tpr_overall 0.6495643259866735
# fpr_overall 0.6495028936043924
# tpr_overall 0.6421217766447691
# fpr_overall 0.6517245317496574
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.329031229019165
# tpr_overall 0.6092947220924801
# fpr_overall 0.6198520481395605
# tpr_overall 0.6161455663762173
# fpr_overall 0.6208933076124054
# tpr_overall 0.608687126188842
# fpr_overall 0.6233439926907264
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# Time that this run took: 194.92099499702454
# time since start: 1567.2400960922241
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe6109d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe6109d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe6109d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe6109d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.200200796127319
# tpr_overall 0.9983185427370388
# fpr_overall 0.9966048360384233
# tpr_overall 0.9982060481804202
# fpr_overall 0.9970915566107731
# tpr_overall 0.9985292675752525
# fpr_overall 0.9974874371859297
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.4208288192749023
# tpr_overall 0.8332087809434844
# fpr_overall 0.7582256817930882
# tpr_overall 0.8364941055868785
# fpr_overall 0.7617450660335361
# tpr_overall 0.8244925973134621
# fpr_overall 0.7625628140703518
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.2322885990142822
# tpr_overall 0.7271835590845399
# fpr_overall 0.6876725184939826
# tpr_overall 0.7305484366991286
# fpr_overall 0.6898056091408221
# tpr_overall 0.725953524855378
# fpr_overall 0.6908405664687072
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.09242582321167
# tpr_overall 0.7589444184960299
# fpr_overall 0.7052280004416474
# tpr_overall 0.7639671963095849
# fpr_overall 0.7096008309838255
# tpr_overall 0.757623296401608
# fpr_overall 0.7108839652809502
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.1799001693725586
# tpr_overall 0.9497898178421298
# fpr_overall 0.9064535718228994
# tpr_overall 0.9521783700666325
# fpr_overall 0.9086214571894939
# tpr_overall 0.9491126581037357
# fpr_overall 0.9124029237094564
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.533496618270874
# tpr_overall 0.7970107426436245
# fpr_overall 0.7386551838357072
# tpr_overall 0.7996412096360841
# fpr_overall 0.7418608102092299
# tpr_overall 0.7933130699088146
# fpr_overall 0.7398926450433988
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.2728817462921143
# tpr_overall 0.08524054180289584
# fpr_overall 0.03742961245445512
# tpr_overall 0.08739108149666837
# fpr_overall 0.037987832022555276
# tpr_overall 0.08765565251495244
# fpr_overall 0.03780264961169484
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.186880588531494
# tpr_overall 0.04955628211116301
# fpr_overall 0.019515292039306614
# tpr_overall 0.05028190671450538
# fpr_overall 0.019824899836771034
# tpr_overall 0.05137758603784685
# fpr_overall 0.018101873001370488
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.320037364959717
# tpr_overall 0.08155067725361981
# fpr_overall 0.03489014022303191
# tpr_overall 0.08257303946694003
# fpr_overall 0.0349606766582579
# tpr_overall 0.08275321109912737
# fpr_overall 0.03409090909090909
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.4000320434570312
# tpr_overall 0.045399346099953296
# fpr_overall 0.016782599094622944
# tpr_overall 0.04490005125576627
# fpr_overall 0.01721323638522036
# tpr_overall 0.04559270516717325
# fpr_overall 0.015532206486980357
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.100
# Time that this run took: 194.73712253570557
# time since start: 1761.977662563324
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe436290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe436290>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe436290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe436290>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.33270263671875
# tpr_overall 0.02185894441849603
# fpr_overall 0.011455228000441648
# tpr_overall 0.0212198872373142
# fpr_overall 0.010951179700252263
# tpr_overall 0.02304147465437788
# fpr_overall 0.011192325262677022
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.64420223236084
# tpr_overall 0.08206445586174685
# fpr_overall 0.03662912664237606
# tpr_overall 0.08303434136340339
# fpr_overall 0.03617747440273038
# tpr_overall 0.08275321109912737
# fpr_overall 0.03540429419826405
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.3352508544921875
# tpr_overall 0.06170014012143858
# fpr_overall 0.02420779507563211
# tpr_overall 0.06253203485392107
# fpr_overall 0.024424988870752336
# tpr_overall 0.06510442200215708
# fpr_overall 0.024154865235267244
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.1667373180389404
# tpr_overall 0.06604390471742176
# fpr_overall 0.026250414044385557
# tpr_overall 0.06447975397232189
# fpr_overall 0.026265024484344857
# tpr_overall 0.06588881262868909
# fpr_overall 0.025525354042941983
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.1465253829956055
# tpr_overall 0.733162073797291
# fpr_overall 0.6887490338964337
# tpr_overall 0.7372629420809841
# fpr_overall 0.6912301528416679
# tpr_overall 0.7315423080694186
# fpr_overall 0.6909547738693468
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.2387537956237793
# tpr_overall 0.003503035964502569
# fpr_overall 0.0038644142652092305
# tpr_overall 0.0035879036391594054
# fpr_overall 0.003353613295741208
# tpr_overall 0.0038239043043435633
# fpr_overall 0.002912288716308817
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.3351452350616455
# tpr_overall 0.5623073330219523
# fpr_overall 0.4359335320746384
# tpr_overall 0.5675550999487442
# fpr_overall 0.4376316960973438
# tpr_overall 0.5618197862535542
# fpr_overall 0.43615806304248517
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.1434590816497803
# tpr_overall 0.0982718355908454
# fpr_overall 0.043143424975157336
# tpr_overall 0.10035879036391594
# fpr_overall 0.04273631102537469
# tpr_overall 0.10000980488283165
# fpr_overall 0.042999086340794884
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.164167881011963
# tpr_overall 0.9979915927136852
# fpr_overall 0.9959147620624931
# tpr_overall 0.9980522808815991
# fpr_overall 0.9964979967354207
# tpr_overall 0.9981370722619864
# fpr_overall 0.9969735038830516
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.2079269886016846
# tpr_overall 0.058337225595516115
# fpr_overall 0.023103676714143755
# tpr_overall 0.060225525371604305
# fpr_overall 0.022970767176138895
# tpr_overall 0.06118246886949701
# fpr_overall 0.022213339424394702
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 0.500
# Time that this run took: 194.53625750541687
# time since start: 1956.514705657959
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.100 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e86dac90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e86dac90>>: AttributeError: module 'gast' has no attribute 'Index'
# ...
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.267458200454712
# tpr_overall 0.33058984910836764
# fpr_overall 0.33753459188426443
# tpr_overall 0.33900543505866815
# fpr_overall 0.3406527835789725
# tpr_overall 0.3312603245554368
# fpr_overall 0.3356486796785304
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 193.9288935661316
# time since start: 2793.132490158081
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe403810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe403810>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe403810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe403810>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  5.117517709732056
# tpr_overall 0.006906012014568847
# fpr_overall 0.008767843932378004
# tpr_overall 0.007162086656169046
# fpr_overall 0.007428844203114744
# tpr_overall 0.008162472062967642
# fpr_overall 0.007175660160734788
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.2003703117370605
# tpr_overall 0.09436639704838938
# fpr_overall 0.0954873003260542
# tpr_overall 0.093869050642556
# fpr_overall 0.09741034667939615
# tpr_overall 0.09289670585948888
# fpr_overall 0.09592422502870264
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  2.762263298034668
# tpr_overall 0.27132112955867743
# fpr_overall 0.2915308107515686
# tpr_overall 0.277797531365876
# fpr_overall 0.2930664120770929
# tpr_overall 0.26557185890584006
# fpr_overall 0.28869115958668196
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.3187568187713623
# tpr_overall 0.32595430679721865
# fpr_overall 0.33082171137353755
# tpr_overall 0.33433230050286994
# fpr_overall 0.3331344352288323
# tpr_overall 0.3244582645029638
# fpr_overall 0.32680826636050514
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.8015334606170654
# tpr_overall 0.3268057329360011
# fpr_overall 0.33216428747568294
# tpr_overall 0.3350942246152283
# fpr_overall 0.3345963362969151
# tpr_overall 0.3257215042269945
# fpr_overall 0.3283582089552239
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.222968816757202
# tpr_overall 0.3271841445532378
# fpr_overall 0.33257528016001314
# tpr_overall 0.33539899426017167
# fpr_overall 0.33501402231636734
# tpr_overall 0.3261101933728501
# fpr_overall 0.32898966704936855
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.109494209289551
# tpr_overall 0.3271841445532378
# fpr_overall 0.33263007918459053
# tpr_overall 0.33539899426017167
# fpr_overall 0.33516319589474314
# tpr_overall 0.3261101933728501
# fpr_overall 0.3291618828932262
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.6062824726104736
# tpr_overall 0.3570313608627785
# fpr_overall 0.3597007973258076
# tpr_overall 0.36496164981967794
# fpr_overall 0.36186526642401096
# tpr_overall 0.3559420853172675
# fpr_overall 0.35723306544202066
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  2.699795722961426
# tpr_overall 0.34681424719738896
# fpr_overall 0.35279612022905993
# tpr_overall 0.35515822624066645
# fpr_overall 0.35568948027925296
# tpr_overall 0.34651637353026915
# fpr_overall 0.35200918484500576
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.2906105518341064
# tpr_overall 0.27491603992242564
# fpr_overall 0.29616132832835573
# tpr_overall 0.27891502006400165
# fpr_overall 0.2976609582910675
# tpr_overall 0.27013895636964336
# fpr_overall 0.29270952927669347
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 196.3277394771576
# time since start: 2989.460486650467
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe940f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe940f90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe940f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe940f90>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  5.387618541717529
# tpr_overall 0.006906012014568847
# fpr_overall 0.008795243444666685
# tpr_overall 0.007009701833697364
# fpr_overall 0.007369174771764425
# tpr_overall 0.00796812749003984
# fpr_overall 0.007233065442020666
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.656935930252075
# tpr_overall 0.09412988978761648
# fpr_overall 0.09540510178918815
# tpr_overall 0.09371666582008432
# fpr_overall 0.0972910078166955
# tpr_overall 0.09250801671363328
# fpr_overall 0.09592422502870264
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.1863698959350586
# tpr_overall 0.2724563644103874
# fpr_overall 0.2929007863660027
# tpr_overall 0.27937217453141666
# fpr_overall 0.29437913956679995
# tpr_overall 0.26654358177047904
# fpr_overall 0.2902985074626866
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.7446329593658447
# tpr_overall 0.32595430679721865
# fpr_overall 0.33079431186124886
# tpr_overall 0.33433230050286994
# fpr_overall 0.3331046005131571
# tpr_overall 0.3244582645029638
# fpr_overall 0.32680826636050514
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.8110642433166504
# tpr_overall 0.3266165271273828
# fpr_overall 0.3317806943036414
# tpr_overall 0.3348910448519328
# fpr_overall 0.334387493287189
# tpr_overall 0.3256243319405306
# fpr_overall 0.3276119402985075
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.5762341022491455
# tpr_overall 0.326711130031692
# fpr_overall 0.3319450913773735
# tpr_overall 0.33499263473358054
# fpr_overall 0.33447699743421444
# tpr_overall 0.3256243319405306
# fpr_overall 0.32784156142365095
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.5336105823516846
# tpr_overall 0.3270895416489286
# fpr_overall 0.3324108830862811
# tpr_overall 0.33519581449687613
# fpr_overall 0.3348946834536667
# tpr_overall 0.32581867651345836
# fpr_overall 0.3288174512055109
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.7285220623016357
# tpr_overall 0.4754268956056951
# fpr_overall 0.4698194372140176
# tpr_overall 0.4879869964951491
# fpr_overall 0.47305925174533087
# tpr_overall 0.47828199397531823
# fpr_overall 0.4691159586681975
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  4.027313232421875
# tpr_overall 0.3481859893098718
# fpr_overall 0.35317971340110144
# tpr_overall 0.3571900238736222
# fpr_overall 0.35607733158303
# tpr_overall 0.34855699154601105
# fpr_overall 0.3510907003444317
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  4.223834276199341
# tpr_overall 0.3469561515538527
# fpr_overall 0.36150916513686054
# tpr_overall 0.3521105297912328
# fpr_overall 0.3624619607375142
# tpr_overall 0.34350403264988827
# fpr_overall 0.3595866819747417
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 203.59578156471252
# time since start: 3193.056316137314
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e84acd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e84acd10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e84acd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6e84acd10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  4.930229663848877
# tpr_overall 0.9984863535310534
# fpr_overall 0.9968764555990903
# tpr_overall 0.9983745618936354
# fpr_overall 0.9971657020108599
# tpr_overall 0.9982508988436498
# fpr_overall 0.9971871412169919
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  3.5990962982177734
# tpr_overall 0.10013717421124829
# fpr_overall 0.10622790914321725
# tpr_overall 0.09844059531670646
# fpr_overall 0.10603257950951728
# tpr_overall 0.09561752988047809
# fpr_overall 0.10619977037887486
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.571490526199341
# tpr_overall 0.0031218958422023556
# fpr_overall 0.004685316601364496
# tpr_overall 0.003403261035200894
# fpr_overall 0.004296199057222985
# tpr_overall 0.002915168593917015
# fpr_overall 0.0044202066590126295
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  3.529991388320923
# tpr_overall 0.06976964192800719
# fpr_overall 0.06669041291065018
# tpr_overall 0.07217961091075328
# fpr_overall 0.06703860612208366
# tpr_overall 0.06889515110290545
# fpr_overall 0.06911595866819747
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  3.515082359313965
# tpr_overall 0.04645002601579869
# fpr_overall 0.03970189330629915
# tpr_overall 0.05135368517295677
# fpr_overall 0.03962050241661197
# tpr_overall 0.04722573122145564
# fpr_overall 0.042709529276693456
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  3.7538909912109375
# tpr_overall 0.7541743531526418
# fpr_overall 0.7263336712606515
# tpr_overall 0.7489206075074922
# fpr_overall 0.7256996240825825
# tpr_overall 0.7525021863764454
# fpr_overall 0.7310562571756601
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.5943212509155273
# tpr_overall 0.7224350787569178
# fpr_overall 0.6913444940680056
# tpr_overall 0.7190531823030426
# fpr_overall 0.689897965272391
# tpr_overall 0.7219900884267807
# fpr_overall 0.6943742824339839
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.3445181846618652
# tpr_overall 0.1056241426611797
# fpr_overall 0.07186892073321095
# tpr_overall 0.11200284451668614
# fpr_overall 0.07312488811981621
# tpr_overall 0.10611213681857934
# fpr_overall 0.07278989667049368
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.5411460399627686
# tpr_overall 0.8482569414881037
# fpr_overall 0.8226703564676549
# tpr_overall 0.8459897394219535
# fpr_overall 0.8217674085565965
# tpr_overall 0.851617918569624
# fpr_overall 0.8281285878300804
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.517836093902588
# tpr_overall 0.8248900241237406
# fpr_overall 0.7878729758610297
# tpr_overall 0.8237415553410881
# fpr_overall 0.7872188078047616
# tpr_overall 0.8272276746671849
# fpr_overall 0.7936854190585534
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 199.21065425872803
# time since start: 3392.267013311386
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe1f3fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe1f3fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe1f3fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fd6fe1f3fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  3.7534871101379395
# tpr_overall 0.9983444491745896
# fpr_overall 0.9968764555990903
# tpr_overall 0.9983237669528116
# fpr_overall 0.9970761978638344
# tpr_overall 0.9982508988436498
# fpr_overall 0.9970723306544202
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  2.8417129516601562
# tpr_overall 0.699257367201173
# fpr_overall 0.6936186535879661
# tpr_overall 0.6911667597907248
# fpr_overall 0.6916283787815503
# tpr_overall 0.701098046837042
# fpr_overall 0.698564867967853
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  2.791599750518799
# tpr_overall 0.0016555508254103401
# fpr_overall 0.0031235444009096638
# tpr_overall 0.001727027988012394
# fpr_overall 0.002953636851840802
# tpr_overall 0.001749101156350209
# fpr_overall 0.0029276693455797934
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  2.8039989471435547
# tpr_overall 0.0031218958422023556
# fpr_overall 0.004493520015343727
# tpr_overall 0.003454055976024788
# fpr_overall 0.004266364341547825
# tpr_overall 0.0030123408803809154
# fpr_overall 0.004305396096440872
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.813450574874878
# tpr_overall 0.6468000567617426
# fpr_overall 0.6428199578047511
# tpr_overall 0.6390511505054096
# fpr_overall 0.6411778745748553
# tpr_overall 0.64648722184433
# fpr_overall 0.6447761194029851
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  2.899019956588745
# tpr_overall 0.6451445059363322
# fpr_overall 0.6389840260843357
# tpr_overall 0.6378828668664601
# fpr_overall 0.6377170475565368
# tpr_overall 0.6461957049849383
# fpr_overall 0.6407577497129736
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  2.812953233718872
# tpr_overall 0.002223168251265314
# fpr_overall 0.0019453653724963696

# %%
# from multiprocessing.pool import ThreadPool as Pool

# pool = Pool(10)
# for result in pool.imap_unordered(task, paths):
#     print(result)

# %%
#   Args:
#     predictions: numpy array of floats representing predictions. Predictions are treated 
#       as positive classification if value is >0, and negative classification if value is <= 0.
#     labels: numpy array of floats representing labels. labels are also treated as positive 
#       classification if value is >0, and negative classification if value is <= 0.
