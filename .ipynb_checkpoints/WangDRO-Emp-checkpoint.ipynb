# %%
import os,sys,json
from glob import glob

os.chdir('/home/avijit/projects/Awareness_vs_Unawareness')
sys.path.insert(0,"/home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode")

# %%
import warnings
warnings.filterwarnings('ignore')

from robustfairnesscode import data, losses, optimization, model, utils, dro_training, softweights_training
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
# Out:
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
def writejson(path,arr,name):
    try:
        os.mkdir(path+'preds/')
    except:
        pass
    f = open(path+'preds/'+name,'w')
    json.dump(arr,f)
    f.close()

# %%
path = 'data/datasets/publiccov/'
synthfols = glob("data/datasets/publiccov/synthetic/*/")
paths = [path]
paths.extend(synthfols)

# %%
def task(path):
    
    print(path)

    if os.path.exists(path+'preds/Softweights_pred.json') == False:
        
        train_df = pd.read_csv(path+'train.csv',header=None)

        train_df.columns = ['AGEP', 'SCHL', 'MAR', 'SEX', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
           'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'PINCP', 'ESR', 'FER', 'RAC1P',
           'PUBCOV']


#         train_df.index = train_df['SEX']

#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})


        train_df = train_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

        test_df = pd.read_csv(path+'test.csv',header=None)

        test_df.columns = ['AGEP', 'SCHL', 'MAR', 'SEX', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
           'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'PINCP', 'ESR', 'FER', 'RAC1P',
           'PUBCOV']


#         test_df.index = test_df['SEX']
        
#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})

        

        X_train = train_df.drop(['PUBCOV'],axis=1)
        X_test = test_df.drop(['PUBCOV'],axis=1)

        Y_train = pd.Series(train_df['PUBCOV'])
        Y_test = pd.Series(test_df['PUBCOV'])

        Y_train = pd.Series(Y_train.factorize(sort=True)[0], index=Y_train.index)
        Y_test = pd.Series(Y_test.factorize(sort=True)[0], index=Y_test.index)

        X_merged = pd.concat([X_train,X_test])

        ohe = make_column_transformer(
            (OneHotEncoder(sparse=False), X_merged.dtypes == 'object'),
            remainder='passthrough', verbose_feature_names_out=False)

        X_merged_temp  = pd.DataFrame(ohe.fit_transform(X_merged), columns=ohe.get_feature_names_out(), index=X_merged.index)

        train_df  = pd.DataFrame(ohe.transform(X_train), columns=ohe.get_feature_names_out(), index=X_train.index)
        test_df = pd.DataFrame(ohe.transform(X_test), columns=ohe.get_feature_names_out(), index=X_test.index)
        
        train_df['PUBCOV'] = Y_train
        test_df['PUBCOV'] = Y_test

        print(train_df.columns)

        LABEL_COLUMN = "PUBCOV"
        FEATURE_NAMES = list(train_df.columns)
        FEATURE_NAMES.remove(LABEL_COLUMN)
        PROTECTED_COLUMNS = ['SEX_Female','SEX_Male']

        PROXY_COLUMNS = PROTECTED_COLUMNS 


        val = dro_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                          PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10,constraint='tpr_and_fpr')

        vall = [float(v) for v in val[0]]

        val_m = [0 if i < 0 else 1 for i in vall]

        writejson(path,val_m,'DRO_pred.json')

        val2 = softweights_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                                   PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10, constraint='tpr_and_fpr')

        val2l = [float(v) for v in val2[0]]

        val_m2 = [0 if i < 0 else 1 for i in val2l]

        writejson(path,val_m2,'Softweights_pred.json')

        return path, 'DRO and SW done'

# %%
for path in paths:
    try:
        task(path)
    except:
        traceback.print_exc()
# Out:
# data/datasets/publiccov/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version0/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version1/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version2/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version3/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version4/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version5/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version6/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version7/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version8/
# data/datasets/publiccov/synthetic/gender_flip_labels0.1_version9/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version0/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version1/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version2/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version3/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version4/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version5/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version6/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version7/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version8/
# data/datasets/publiccov/synthetic/gender_flip_labels0.2_version9/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version0/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version1/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version2/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version3/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version4/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version5/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version6/
# data/datasets/publiccov/synthetic/gender_flip_labels0.3_version7/
# Index(['SCHL_1 or more years of college credit, no degree',
#        'SCHL_12th grade - no diploma', 'SCHL_Associate's degree',
#        'SCHL_Bachelor's degree', 'SCHL_Doctorate degree',
#        'SCHL_GED or alternative credential', 'SCHL_Grade 1', 'SCHL_Grade 10',
#        'SCHL_Grade 11', 'SCHL_Grade 2', 'SCHL_Grade 3', 'SCHL_Grade 4',
#        'SCHL_Grade 5', 'SCHL_Grade 6', 'SCHL_Grade 7', 'SCHL_Grade 8',
#        'SCHL_Grade 9', 'SCHL_Kindergarten', 'SCHL_Master's degree',
#        'SCHL_No schooling completed', 'SCHL_Nursery school, preschool',
#        'SCHL_Professional degree beyond a bachelor's degree',
#        'SCHL_Regular high school diploma',
#        'SCHL_Some college, but less than 1 year', 'MAR_Divorced',
#        'MAR_Married', 'MAR_Never married or under 15 years old',
#        'MAR_Separated', 'MAR_Widowed', 'SEX_Female', 'SEX_Male',
#        'DIS_With a disability', 'DIS_Without a disability',
#        'ESP_Both parents in labor force', 'ESP_Father in the labor force',
#        'ESP_Father not in labor force living with mother:',
#        'ESP_Father only in labor force', 'ESP_Mother in the labor force',
#        'ESP_Mother not in labor force', 'ESP_Mother only in labor force',
#        'ESP_N/A (not own child of householder, and not child in subfamily) Living with two parents:',
#        'ESP_Neither parent in labor force living with one parent: Living with father:',
#        'CIT_Born abroad of American parent(s)',
#        'CIT_Born in Puerto Rico, Guam, the U.S. Virgin Islands, or the Northern Marianas',
#        'CIT_Born in the U.S.', 'CIT_Not a citizen of the U.S.',
#        'CIT_U.S. citizen by naturalization',
#        'MIG_No, different house in US or Puerto Rico',
#        'MIG_No, outside US and Puerto Rico', 'MIG_Yes, same house (nonmovers)',
#        'MIL_N/A (less than 17 years old)', 'MIL_Never served in the military',
#        'MIL_Now on active duty', 'MIL_On active duty in the past, but not now',
#        'MIL_Only on active duty for training in Reserves/National Guard',
#        'ANC_Multiple', 'ANC_Not reported', 'ANC_Single', 'ANC_Unclassified',
#        'NATIVITY_Foreign born', 'NATIVITY_Native', 'DEAR_No', 'DEAR_Yes',
#        'DEYE_No', 'DEYE_Yes', 'DREM_No', 'DREM_Yes',
#        'ESR_Armed forces, at work',
#        'ESR_Armed forces, with a job but not at work',
#        'ESR_Civilian employed, at work',
#        'ESR_Civilian employed, with a job but not at work',
#        'ESR_N/A (less than 16 years old)', 'ESR_Not in labor force',
#        'ESR_Unemployed',
#        'FER_N/A (less than 15 years/greater than 50 years/ male)', 'FER_No',
#        'FER_Yes', 'RAC1P_Alaska', 'RAC1P_American', 'RAC1P_Asian',
#        'RAC1P_Black', 'RAC1P_Native', 'RAC1P_Some', 'RAC1P_Two', 'RAC1P_White',
#        'AGEP', 'PINCP', 'PUBCOV'],
#       dtype='object')
# Split 1 of 1
# time since start: 0.20350241661071777
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.9778659343719482
# tpr_overall 0.3304984644460194
# fpr_overall 0.3310668165492282
# tpr_overall 0.32516024010580935
# fpr_overall 0.32891167615584105
# tpr_overall 0.3321678321678322
# fpr_overall 0.3339075509618145
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  2.985704183578491
# tpr_overall 0.32964800377982517
# fpr_overall 0.33079264113179613
# tpr_overall 0.3241937124834673
# fpr_overall 0.32852416013354396
# tpr_overall 0.3310994560994561
# fpr_overall 0.3335630203847258
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  3.86177134513855
# tpr_overall 0.3315379163713678
# fpr_overall 0.332492528719875
# tpr_overall 0.326431986977312
# fpr_overall 0.3309088741169106
# tpr_overall 0.33294483294483296
# fpr_overall 0.3358598908986506
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.874131202697754
# tpr_overall 0.33900307110796124
# fpr_overall 0.34036136320017546
# tpr_overall 0.3346220368297894
# fpr_overall 0.3387784302620204
# tpr_overall 0.3404234654234654
# fpr_overall 0.3423485501004881
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  3.4460690021514893
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  3.392698049545288
# tpr_overall 0.41006378454996456
# fpr_overall 0.4302634825761522
# tpr_overall 0.4052802930104792
# fpr_overall 0.42528393000864456
# tpr_overall 0.41054778554778554
# fpr_overall 0.42939994257823716
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 195.2057294845581
# time since start: 5289.527335166931
# begin optimizing learning rate p list: [0.1, 0.1, 0.1]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2a2ce41850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2a2ce41850>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2a2ce41850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2a2ce41850>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  3.8881733417510986
# tpr_overall 0.9980628395936688
# fpr_overall 0.9969292353247607
# tpr_overall 0.9986265133787771
# fpr_overall 0.9968104450472471
# tpr_overall 0.9982517482517482
# fpr_overall 0.9974734424346827
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  2.9878578186035156
# tpr_overall 0.0035908339239310184
# fpr_overall 0.004194883886710718
# tpr_overall 0.0027978431173059314
# fpr_overall 0.004352103019644081
# tpr_overall 0.0027195027195027195
# fpr_overall 0.0037324145851277634
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  3.2351343631744385
# tpr_overall 0.018757382471060714
# fpr_overall 0.021714693060620186
# tpr_overall 0.019025333197680332
# fpr_overall 0.021074909828002503
# tpr_overall 0.018842268842268844
# fpr_overall 0.020327304048234282
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  2.9173943996429443
# tpr_overall 0.6607606898180959
# fpr_overall 0.6740328462150084
# tpr_overall 0.6659375317936718
# fpr_overall 0.6766625927802784
# tpr_overall 0.657051282051282
# fpr_overall 0.6728682170542636
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  2.928941488265991
# tpr_overall 0.34472005669737776
# fpr_overall 0.4956269020919584
# tpr_overall 0.34271034693254654
# fpr_overall 0.4948877693981578
# tpr_overall 0.344017094017094
# fpr_overall 0.4886017800746483
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  2.65537166595459
# tpr_overall 0.005197259626742263
# fpr_overall 0.005922189016532777
# tpr_overall 0.005443076610031539
# fpr_overall 0.006170447431961129
# tpr_overall 0.004370629370629371
# fpr_overall 0.005684754521963824
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  2.9486374855041504
# tpr_overall 0.0020789038506969053
# fpr_overall 0.0033723576344144982
# tpr_overall 0.0018313154949638824
# fpr_overall 0.003696306674218261
# tpr_overall 0.0018453768453768455
# fpr_overall 0.0029285099052540915
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  3.2018892765045166
# tpr_overall 0.6173871958421923
# fpr_overall 0.6261618183313684

# %%
# from multiprocessing.pool import ThreadPool as Pool

# pool = Pool(10)
# for result in pool.imap_unordered(task, paths):
#     print(result)

# %%
#   Args:
#     predictions: numpy array of floats representing predictions. Predictions are treated 
#       as positive classification if value is >0, and negative classification if value is <= 0.
#     labels: numpy array of floats representing labels. labels are also treated as positive 
#       classification if value is >0, and negative classification if value is <= 0.
