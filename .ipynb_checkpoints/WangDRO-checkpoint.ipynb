# %%
import os,sys,json
from glob import glob

os.chdir('/home/avijit/projects/Awareness_vs_Unawareness')
sys.path.insert(0,"/home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode")

# %%
import warnings
warnings.filterwarnings('ignore')

from robustfairnesscode import data, losses, optimization, model, utils, dro_training, softweights_training
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
# Out:
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
def writejson(path,arr,name):
    try:
        os.mkdir(path+'preds/')
    except:
        pass
    f = open(path+'preds/'+name,'w')
    json.dump(arr.tolist(),f)
    f.close()

# %%
path = 'data/datasets/uci_adult/'
synthfols = glob("data/datasets/uci_adult/synthetic/*/")
paths = [path]
paths.extend(synthfols)

# %%
def task(path):
    
    train_df = pd.read_csv(path+'train.csv',header=None)

    test_df = pd.read_csv(path+'test.csv',header=None)

    train_df.columns = ['age', 'workclass', 'fnlwgt','education', 'education-num', 'marital-status',
           'occupation', 'relationship', 'race', 'sex', 'capital-gain',
           'capital-loss', 'hours-per-week', 'native-country','income']

    test_df.columns = ['age', 'workclass', 'fnlwgt','education', 'education-num', 'marital-status',
           'occupation', 'relationship', 'race', 'sex', 'capital-gain',
           'capital-loss', 'hours-per-week', 'native-country','income']

    #test_df.index = test_df['sex']

    test_df = test_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

    # train_df['sex'] = train_df['sex'].map({'Male': 1, 'Female': 0})
    # test_df['sex'] = test_df['sex'].map({'Male': 1, 'Female': 0})

    X_train = train_df.drop(['income'],axis=1)
    X_test = test_df.drop(['income'],axis=1)

    y_train = pd.Series(train_df['income'])
    y_test = pd.Series(test_df['income'])


    y_train = pd.Series(y_train.factorize(sort=True)[0], index=y_train.index)
    y_test = pd.Series(y_test.factorize(sort=True)[0], index=y_test.index)

    X_merged = pd.concat([X_train,X_test])

    ohe = make_column_transformer(
        (OneHotEncoder(sparse=False), X_merged.dtypes == 'object'),
        remainder='passthrough', verbose_feature_names_out=False)

    X_merged_temp  = pd.DataFrame(ohe.fit_transform(X_merged), columns=ohe.get_feature_names_out(), index=X_merged.index)

    train_df  = pd.DataFrame(ohe.transform(X_train), columns=ohe.get_feature_names_out(), index=X_train.index)
    test_df = pd.DataFrame(ohe.transform(X_test), columns=ohe.get_feature_names_out(), index=X_test.index)

    train_df['income'] = y_train
    test_df['income'] = y_test

    print(train_df.columns)

    LABEL_COLUMN = "income"
    FEATURE_NAMES = list(train_df.columns)
    FEATURE_NAMES.remove(LABEL_COLUMN)
    PROTECTED_COLUMNS = ['sex_Female','sex_Male']

    PROXY_COLUMNS = PROTECTED_COLUMNS 
    
    
    val = dro_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                      PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 1,constraint='tpr_and_fpr')
    
    print(val)
    
#     val_m = [0 if i < 0 else 1 for i in list(np.array(val))]
    
#     writejson(path,val_m,'DRO_pred.json')
    
#     val2 = softweights_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
#                                                                PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10, constraint='tpr_and_fpr')
    
#     val_m2 = [0 if i < 0 else 1 for i in list(np.array(val2))]
        
#     writejson(path,val_m2,'Softweights_pred.json')
    return val
    
    return path, 'DRO and SW done'

# %%
task(path)
# Out:
# Index(['workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_State-gov',
#        'workclass_Without-pay', 'education_10th',
#        ...
#        'native-country_United-States', 'native-country_Vietnam',
#        'native-country_Yugoslavia', 'age', 'fnlwgt', 'education-num',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'income'],
#       dtype='object', length=109)
# Split 1 of 1
# time since start: 0.07526135444641113
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:70: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fa17be85dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fa17be85dd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fa17be85dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fa17be85dd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:85: The name tf.losses.hinge_loss is deprecated. Please use tf.compat.v1.losses.hinge_loss instead.
#
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:157: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# minibatch is off
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:169: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.130742311477661
# tpr_overall 0.005704365079365079
# fpr_overall 0.0
# tpr_overall 0.006300866369125755
# fpr_overall 0.0
# tpr_overall 0.009100364014560582
# fpr_overall 0.0
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 9.043803453445435
# best_learning_rate_theta, 0.001
# best_learning_rate_lambda 0.1
# best_learning_rate_p_list [0.001, 0.001, 0.001]
# time it took for this split 9.12078595161438
# (array([[-21888.32  ],
#        [ -8666.142 ],
#        [-32517.568 ],
#        ...,
#        [-36188.1   ],
#        [ -7410.5815],
#        [-17578.166 ]], dtype=float32), array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]], dtype=float32))
# ('data/datasets/uci_adult/', 'DRO and SW done')

# %%
for path in paths:
    try:
        task(path)
    except:
        pass
# Out:
# Index(['workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_State-gov',
#        'workclass_Without-pay', 'education_10th',
#        ...
#        'native-country_United-States', 'native-country_Vietnam',
#        'native-country_Yugoslavia', 'age', 'fnlwgt', 'education-num',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'income'],
#       dtype='object', length=109)
# Split 1 of 1
# time since start: 0.07728886604309082
# begin optimizing learning rate p list: [0.001, 0.001, 0.001]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:70: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f664b58f550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f664b58f550>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f664b58f550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f664b58f550>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:71: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:85: The name tf.losses.hinge_loss is deprecated. Please use tf.compat.v1.losses.hinge_loss instead.
#
# WARNING:tensorflow:From /home/avijit/anaconda3/envs/oscar/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:157: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# minibatch is off
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:169: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  2.0863568782806396
# tpr_overall 0.005704365079365079
# fpr_overall 0.0
# tpr_overall 0.006300866369125755
# fpr_overall 0.0
# tpr_overall 0.009100364014560582
# fpr_overall 0.0
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  1.1022708415985107
# tpr_overall 0.013888888888888888
# fpr_overall 0.0
# tpr_overall 0.01942767130480441
# fpr_overall 8.459521191100583e-05
# tpr_overall 0.01794071762870515
# fpr_overall 0.0
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  1.1708612442016602
# tpr_overall 0.024305555555555556
# fpr_overall 0.0
# tpr_overall 0.028878970858493044
# fpr_overall 0.0003383808476440233
# tpr_overall 0.02782111284451378
# fpr_overall 0.0
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  1.1581029891967773
# tpr_overall 0.0441468253968254
# fpr_overall 0.0007752538956508257
# tpr_overall 0.04804410606458388
# fpr_overall 0.0008459521191100584
# tpr_overall 0.046021840873634944
# fpr_overall 0.0008041817450743868
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  1.656611680984497
# tpr_overall 0.19990079365079366
# fpr_overall 0.021939685246918365
# tpr_overall 0.20950380677343133
# fpr_overall 0.018357160984688266
# tpr_overall 0.19916796671866874
# fpr_overall 0.021632488942501006
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  1.2059049606323242
# tpr_overall 0.15079365079365079
# fpr_overall 0.008992945189549578
# tpr_overall 0.154371226043581
# fpr_overall 0.007444378648168513
# tpr_overall 0.1440457618304732
# fpr_overall 0.00981101728990752
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  1
>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  10
# finish loop  1 in loops  10
# time for this loop  2.7168025970458984
# tpr_overall 0.041914682539682536
# fpr_overall 0.0006202031165206605
# tpr_overall 0.045156208978734576
# fpr_overall 0.0007613569071990526
# tpr_overall 0.044201768070722826
# fpr_overall 0.0005629272215520708
# start loop  2 in loops  10
# finish loop  2 in loops  10
# time for this loop  1.1675059795379639
# tpr_overall 0.31125992063492064
# fpr_overall 0.06829986820683774
# tpr_overall 0.3137306379627199
# fpr_overall 0.07232890618391
# tpr_overall 0.3081123244929797
# fpr_overall 0.07028548451950141
# start loop  3 in loops  10
# finish loop  3 in loops  10
# time for this loop  1.1065313816070557
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# start loop  4 in loops  10
# finish loop  4 in loops  10
# time for this loop  1.3544421195983887
# tpr_overall 0.2482638888888889
# fpr_overall 0.03139778277385844
# tpr_overall 0.2509845103701759
# fpr_overall 0.031723204466627186
# tpr_overall 0.2420696827873115
# fpr_overall 0.033051869722557296
# start loop  5 in loops  10
# finish loop  5 in loops  10
# time for this loop  1.4156343936920166
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# tpr_overall 1.0
# fpr_overall 1.0
# start loop  6 in loops  10
# finish loop  6 in loops  10
# time for this loop  1.1050524711608887
# tpr_overall 0.19766865079365079
# fpr_overall 0.01728816187301341
# tpr_overall 0.20267786820687844
# fpr_overall 0.014550376448693003
# tpr_overall 0.19630785231409256
# fpr_overall 0.016807398472054685
# start loop  7 in loops  10
# finish loop  7 in loops  10
# time for this loop  1.2944612503051758
# tpr_overall 0.9412202380952381
# fpr_overall 0.9475153112644391
# tpr_overall 0.9459175636650039
# fpr_overall 0.9470433973437103
# tpr_overall 0.9490379615184608
# fpr_overall 0.9506232408524327
# start loop  8 in loops  10
# finish loop  8 in loops  10
# time for this loop  1.0676453113555908
# tpr_overall 0.006696428571428571
# fpr_overall 0.0016280331808667338
# tpr_overall 0.006300866369125755
# fpr_overall 0.0012689281786650876
# tpr_overall 0.004160166406656267
# fpr_overall 0.001769199839163651
# start loop  9 in loops  10
# finish loop  9 in loops  10
# time for this loop  1.0558381080627441
# tpr_overall 0.017857142857142856
# fpr_overall 0.0007752538956508257
# tpr_overall 0.024153321081648728
# fpr_overall 0.0005921664833770408
# tpr_overall 0.022100884035361413
# fpr_overall 0.0012866907921190189
# start loop  10 in loops  10
# finish loop  10 in loops  10
# time for this loop  1.0411174297332764
# tpr_overall 0.9987599206349206
# fpr_overall 0.9973641367547872
# tpr_overall 0.9973746390128643
# fpr_overall 0.9964470010997377
# tpr_overall 0.9973998959958398
# fpr_overall 0.9969441093687174
# Finished learning rate p list [0.1, 0.1, 0.1]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# Time that this run took: 77.50356483459473
# best_learning_rate_theta, 0.1
# best_learning_rate_lambda 0.1
# best_learning_rate_p_list [0.01, 0.01, 0.01]
# time it took for this split 2562.09464097023
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0a22ecfdc6a0> in <module>
#       1 for path in paths:
# ----> 2     task(path)
#
# <ipython-input-6-1b4548a5fee4> in task(path)
#      57                                                       PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10,constraint='tpr_and_fpr')
#      58
# ---> 59     val_m = [0 if i < 0 else 1 for i in list(np.array(val))]
#      60
#      61     writejson(path,val_m,'DRO_pred.json')
#
# <ipython-input-6-1b4548a5fee4> in <listcomp>(.0)
#      57                                                       PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 10,constraint='tpr_and_fpr')
#      58
# ---> 59     val_m = [0 if i < 0 else 1 for i in list(np.array(val))]
#      60
#      61     writejson(path,val_m,'DRO_pred.json')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# from multiprocessing.pool import ThreadPool as Pool

# pool = Pool(10)
# for result in pool.imap_unordered(task, paths):
#     print(result)

# %%
#   Args:
#     predictions: numpy array of floats representing predictions. Predictions are treated 
#       as positive classification if value is >0, and negative classification if value is <= 0.
#     labels: numpy array of floats representing labels. labels are also treated as positive 
#       classification if value is >0, and negative classification if value is <= 0.
