# %%
import os,sys,json
from glob import glob

os.chdir('/home/avijit/projects/Awareness_vs_Unawareness')
sys.path.insert(0,"/home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode")

# %%
import warnings
warnings.filterwarnings('ignore')

from robustfairnesscode import data, losses, optimization, model, utils, dro_training, softweights_training
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
# Out:
# WARNING:tensorflow:From /home/avijit/projects/Awareness_vs_Unawareness/robustfairnesscode/dro_training.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
import traceback

# %%
def writejson(path,arr,name):
    try:
        os.mkdir(path+'preds/')
    except:
        pass
    f = open(path+'preds/'+name,'w')
    json.dump(arr,f)
    f.close()

# %%
path = 'data/datasets/employment_tx/'
synthfols = glob("data/datasets/employment_tx/synthetic/*/")
paths = [path]
paths.extend(synthfols)

path = 'data/datasets/employment_ny/'
synthfols = glob("data/datasets/employment_ny/synthetic/*/")
paths.append(path)
paths.extend(synthfols)

path = 'data/datasets/employment_ca/'
synthfols = glob("data/datasets/employment_ca/synthetic/*/")
paths.append(path)
paths.extend(synthfols)

# %%
def task(path):
    
    print(path)

    if True:#os.path.exists(path+'preds/Softweights_pred.json') == False:
        
        train_df = pd.read_csv(path+'train.csv',header=None)

        train_df.columns = ['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
       'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR']


#         train_df.index = train_df['SEX']

#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})


        train_df = train_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

        test_df = pd.read_csv(path+'test.csv',header=None)

        test_df.columns = ['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
       'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR']


#         test_df.index = test_df['SEX']
        
#         train_df['SEX'] = train_df['SEX'].map({'Male': 1, 'Female': 0})

        

        X_train = train_df.drop(['ESR'],axis=1)
        X_test = test_df.drop(['ESR'],axis=1)

        Y_train = pd.Series(train_df['ESR'])
        Y_test = pd.Series(test_df['ESR'])

        Y_train = pd.Series(Y_train.factorize(sort=True)[0], index=Y_train.index)
        Y_test = pd.Series(Y_test.factorize(sort=True)[0], index=Y_test.index)

        X_merged = pd.concat([X_train,X_test])

        ohe = make_column_transformer(
            (OneHotEncoder(sparse=False), X_merged.dtypes == 'object'),
            remainder='passthrough', verbose_feature_names_out=False)

        X_merged_temp  = pd.DataFrame(ohe.fit_transform(X_merged), columns=ohe.get_feature_names_out(), index=X_merged.index)

        train_df  = pd.DataFrame(ohe.transform(X_train), columns=ohe.get_feature_names_out(), index=X_train.index)
        test_df = pd.DataFrame(ohe.transform(X_test), columns=ohe.get_feature_names_out(), index=X_test.index)
        
        train_df['ESR'] = Y_train
        test_df['ESR'] = Y_test

        print(train_df.columns)

        LABEL_COLUMN = "ESR"
        FEATURE_NAMES = list(train_df.columns)
        FEATURE_NAMES.remove(LABEL_COLUMN)
        PROTECTED_COLUMNS = ['SEX_Female','SEX_Male']

        PROXY_COLUMNS = PROTECTED_COLUMNS 


        val,_,_,_ = dro_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                          PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 1,constraint='tpr_and_fpr')

        vall = [float(v) for v in val[0]]

        val_m = [0 if i < 0 else 1 for i in vall]

        writejson(path,val_m,'DRO_pred.json')

        val2,_,_,_ = softweights_training.get_results_for_learning_rates(train_df, test_df, FEATURE_NAMES, 
                                                                   PROTECTED_COLUMNS, PROXY_COLUMNS, LABEL_COLUMN, num_loops = 1, constraint='tpr_and_fpr')

        val2l = [float(v) for v in val2[0]]

        val_m2 = [0 if i < 0 else 1 for i in val2l]

        writejson(path,val_m2,'Softweights_pred.json')

        return path, 'DRO and SW done'

# %%
import random
random.shuffle(paths)
for path in paths:
    try:
        task(path)
    except:
        traceback.print_exc()
# Out:
# data/datasets/employment_ny/synthetic/gender_flip_labels0.7_version3/
# Index(['SCHL_1 or more years of college credit, no degree',
#        'SCHL_12th grade - no diploma', 'SCHL_Associate's degree',
#        'SCHL_Bachelor's degree', 'SCHL_Doctorate degree',
#        'SCHL_GED or alternative credential', 'SCHL_Grade 1', 'SCHL_Grade 10',
#        'SCHL_Grade 11', 'SCHL_Grade 2', 'SCHL_Grade 3', 'SCHL_Grade 4',
#        'SCHL_Grade 5', 'SCHL_Grade 6', 'SCHL_Grade 7', 'SCHL_Grade 8',
#        'SCHL_Grade 9', 'SCHL_Kindergarten', 'SCHL_Master's degree',
#        'SCHL_N/A (less than 3 years old)', 'SCHL_No schooling completed',
#        'SCHL_Nursery school, preschool',
#        'SCHL_Professional degree beyond a bachelor's degree',
#        'SCHL_Regular high school diploma',
#        'SCHL_Some college, but less than 1 year', 'MAR_Divorced',
#        'MAR_Married', 'MAR_Never married or under 15 years old',
#        'MAR_Separated', 'MAR_Widowed', 'RELP_Adopted son or daughter',
#        'RELP_Biological son or daughter', 'RELP_Brother or sister',
#        'RELP_Father or mother', 'RELP_Foster child', 'RELP_Grandchild',
#        'RELP_Housemate or roommate', 'RELP_Husband/wife',
#        'RELP_Institutionalized group quarters population',
#        'RELP_Noninstitutionalized group quarters population',
#        'RELP_Other nonrelative', 'RELP_Other relative', 'RELP_Parent-in-law',
#        'RELP_Reference person', 'RELP_Roomer or boarder',
#        'RELP_Son-in-law or daughter-in-law', 'RELP_Stepson or stepdaughter',
#        'RELP_Unmarried partner', 'DIS_With a disability',
#        'DIS_Without a disability', 'ESP_Both parents in labor force',
#        'ESP_Father in the labor force',
#        'ESP_Father not in labor force living with mother:',
#        'ESP_Father only in labor force', 'ESP_Mother in the labor force',
#        'ESP_Mother not in labor force', 'ESP_Mother only in labor force',
#        'ESP_N/A (not own child of householder, and not child in subfamily) Living with two parents:',
#        'ESP_Neither parent in labor force living with one parent: Living with father:',
#        'CIT_Born abroad of American parent(s)',
#        'CIT_Born in Puerto Rico, Guam, the U.S. Virgin Islands, or the Northern Marianas',
#        'CIT_Born in the U.S.', 'CIT_Not a citizen of the U.S.',
#        'CIT_U.S. citizen by naturalization', 'MIG_N/A (less than 1 year old)',
#        'MIG_No, different house in US or Puerto Rico',
#        'MIG_No, outside US and Puerto Rico', 'MIG_Yes, same house (nonmovers)',
#        'MIL_N/A (less than 17 years old)', 'MIL_Never served in the military',
# Finished learning rate p list [0.001, 0.001, 0.001]
# Finished optimizing learning rate theta: 0.100 learning rate lambda: 2.000
# Time that this run took: 11.485474348068237
# time since start: 145.05031180381775
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9b4ae10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9b4ae10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9b4ae10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9b4ae10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.5546765327453613
# tpr_overall 0.31668504805419884
# fpr_overall 0.3097246427326595
# tpr_overall 0.31596711380354825
# fpr_overall 0.3068258112644536
# tpr_overall 0.31543624161073824
# fpr_overall 0.3173704832390074
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.100
# Time that this run took: 11.160659551620483
# time since start: 156.2112193107605
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7423e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7423e90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7423e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7423e90>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.871746778488159
# tpr_overall 0.32984086970222154
# fpr_overall 0.3261066573719066
# tpr_overall 0.32825616616183473
# fpr_overall 0.3218948153674002
# tpr_overall 0.32640366672123095
# fpr_overall 0.3317370483239007
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 0.500
# Time that this run took: 11.53634786605835
# time since start: 167.74781465530396
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7fdbe50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7fdbe50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7fdbe50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7fdbe50>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.807283401489258
# tpr_overall 0.3454387899795179
# fpr_overall 0.3333565702335308
# tpr_overall 0.34322803980960626
# fpr_overall 0.32868332711674747
# tpr_overall 0.3412997217220494
# fpr_overall 0.34058917428529967
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 1.000
# Time that this run took: 11.390519618988037
# time since start: 179.13858222961426
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7f7a8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7f7a8d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7f7a8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7f7a8d0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  3.3266541957855225
# tpr_overall 0.3120371829210651
# fpr_overall 0.3196932729173928
# tpr_overall 0.3113803548247512
# fpr_overall 0.31525550167847816
# tpr_overall 0.30921591095105583
# fpr_overall 0.3237556232767378
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.001 learning rate lambda: 2.000
# Time that this run took: 11.931623220443726
# time since start: 191.0704698562622
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7246150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7246150>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7246150>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe7246150>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.640202760696411
# tpr_overall 0.9327241216322673
# fpr_overall 0.4750784245381666
# tpr_overall 0.9338814366075292
# fpr_overall 0.46713912719134654
# tpr_overall 0.931903748567687
# fpr_overall 0.4725003627920476
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.100
# Time that this run took: 11.391543626785278
# time since start: 202.46226143836975
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe8db2f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe8db2f10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe8db2f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe8db2f10>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.586655616760254
# tpr_overall 0.9837718607216007
# fpr_overall 0.6024398745207389
# tpr_overall 0.9836434443963652
# fpr_overall 0.5935844834017158
# tpr_overall 0.984449173350794
# fpr_overall 0.5994775794514584
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 0.500
# Time that this run took: 11.251904010772705
# time since start: 213.71419644355774
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9413fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9413fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9413fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9413fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1
# finish loop  1 in loops  1
# time for this loop  2.6468496322631836
# tpr_overall 0.664802268788404
# fpr_overall 0.24796096200766818
# tpr_overall 0.6617048896581567
# fpr_overall 0.2504289444237225
# tpr_overall 0.6583728924537567
# fpr_overall 0.25119721375707443
# Finished learning rate p list [0.01, 0.01, 0.01]
# Finished optimizing learning rate theta: 0.010 learning rate lambda: 1.000
# Time that this run took: 11.326417922973633
# time since start: 225.04088950157166
# begin optimizing learning rate p list: [0.01, 0.01, 0.01]
# begin optimizing learning rate theta: 0.010 learning rate lambda: 2.000
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9a87fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9a87fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9a87fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1fe9a87fd0>>: AttributeError: module 'gast' has no attribute 'Index'
# minibatch is off
# start loop  1 in loops  1

# %%
# from multiprocessing.pool import ThreadPool as Pool

# pool = Pool(10)
# for result in pool.imap_unordered(task, paths):
#     print(result)

# %%
#   Args:
#     predictions: numpy array of floats representing predictions. Predictions are treated 
#       as positive classification if value is >0, and negative classification if value is <= 0.
#     labels: numpy array of floats representing labels. labels are also treated as positive 
#       classification if value is >0, and negative classification if value is <= 0.
